# %% [markdown]
# <a href="https://colab.research.google.com/github/GauloPi/testeee/blob/main/Importa%C3%A7%C3%A3o_direita_dados_yahoo_metatrader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CÓDIGO FEITO PARA IMPORTAR DADOS DE PREÇOS HISTÓRICOS DE ATIVOS FINANCEIROS
# (DATA, HORA, ABERTURA, MÁXIMA, MÍNIMA, FECHAMENTO E VOLUME NEGOCIADO) DO
# YAHOO FINANCE DIRETO PARA O METATRADER FIZ ISSO PARA REALIZAR BACKTESTS


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# A ORDEM DOS DADOS DEVE SER A SEGUINTE ---> Date, Time, Open, High, Low, Close, Volume

import pdb
import yfinance as yf
import pandas as pd # Importa o pandas explicitamente

# Definindo o ticker e o período desejado (VER O NOME NO YAHOO)
# O CÓDIGO DO PAPEL PODE SER ENCONTRADO NO https://finance.yahoo.com/
# POR EXEMPLO VALE3 DEVE-SE ESCREVER VALE3.SA
ticker = input("Digite o código do papel (max period): ")
periodo = "max"

# Baixando os dados históricos e armazenando em um DataFrame
df = yf.download(ticker, period=periodo)
# Out:
# Digite o código do papel (max period): GOLD11.SA
# /tmp/ipython-input-1145995340.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period=periodo)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker     GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA
# Date
# 2020-12-16     10.30     18.90     10.16     12.00    163307
# 2020-12-17     10.30     10.60     10.15     10.40    457235
# 2020-12-18     10.32     10.41     10.25     10.38    773278
# 2020-12-21     10.38     10.53     10.33     10.40    314610
# 2020-12-22     10.39     10.45     10.32     10.44    496482

# %%
# COMO JÁ OCORREU ERROS DE FORMATO PRECISO EXCLUIR OS CARACTERES EXCEDENTES DA
# COLUNA TIME

# TRANSFORMO O INDICE "DATA" PARA COLUNA PARA FACILITAR A MANIPULAÇÃO
df = df.reset_index()

# Rename the 'Date' column for clarity if its not named 'Date'
# df = df.rename(columns={df.columns[0]: 'Date'})
# Remove the values beyond the 10th character in the 'Date' column
df['Date'] = df['Date'].astype(str).str[:10]

# If you need 'Date' as index again:
# df = df.set_index('Date')
df.head()
# Out:
# Price         Date     Close      High       Low      Open    Volume
# Ticker             GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA
# 0       2020-12-16     10.30     18.90     10.16     12.00    163307
# 1       2020-12-17     10.30     10.60     10.15     10.40    457235
# 2       2020-12-18     10.32     10.41     10.25     10.38    773278
# 3       2020-12-21     10.38     10.53     10.33     10.40    314610
# 4       2020-12-22     10.39     10.45     10.32     10.44    496482

# %%
# Using dataframe df: Preciso que adiciona uma coluna entre a primeira coluna e a segunda coluna, que tenha a seguinte informação (00:00:00)

# Insert a new column named 'Time' at the second position (index 1)
# The new column will contain the value '00:00:00' for all rows

df.insert(1, 'Time', '00:00:00')
df.head()
# Out:
# Price         Date      Time     Close      High       Low      Open    Volume
# Ticker                       GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA
# 0       2020-12-16  00:00:00     10.30     18.90     10.16     12.00    163307
# 1       2020-12-17  00:00:00     10.30     10.60     10.15     10.40    457235
# 2       2020-12-18  00:00:00     10.32     10.41     10.25     10.38    773278
# 3       2020-12-21  00:00:00     10.38     10.53     10.33     10.40    314610
# 4       2020-12-22  00:00:00     10.39     10.45     10.32     10.44    496482

# %%
# CASO VENHA A COLUNA ADJ CLOSE (eu prefiro nao usar)

if 'Adj Close' in df.columns:
    df = df.drop(columns=['Adj Close'])
    print("Coluna 'Adj Close' deletada.")
else:
    print("Coluna 'Adj Close' não encontrada no DataFrame.")

df.head()
# Out:
# Column 'Adj Close' not found in the DataFrame.
# Price         Date      Time     Close      High       Low      Open    Volume
# Ticker                       GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA
# 0       2020-12-16  00:00:00     10.30     18.90     10.16     12.00    163307
# 1       2020-12-17  00:00:00     10.30     10.60     10.15     10.40    457235
# 2       2020-12-18  00:00:00     10.32     10.41     10.25     10.38    773278
# 3       2020-12-21  00:00:00     10.38     10.53     10.33     10.40    314610
# 4       2020-12-22  00:00:00     10.39     10.45     10.32     10.44    496482

# %%
# Colocar na ordem OHLC

df = df[['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Volume']]

df.head()
# Out:
# Price         Date      Time      Open      High       Low     Close    Volume
# Ticker                       GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA GOLD11.SA
# 0       2020-12-16  00:00:00     12.00     18.90     10.16     10.30    163307
# 1       2020-12-17  00:00:00     10.40     10.60     10.15     10.30    457235
# 2       2020-12-18  00:00:00     10.38     10.41     10.25     10.32    773278
# 3       2020-12-21  00:00:00     10.40     10.53     10.33     10.38    314610
# 4       2020-12-22  00:00:00     10.44     10.45     10.32     10.39    496482

# %%
import os
print(os.getcwd())


df.to_csv(f'/content/drive/My Drive/Invest/ALGOTRADE/Inserção de dados/OUTPUT DATA COLLAB/{ticker}.csv', index=False)

# dfAdj.to_csv('/content/drive/My Drive/Invest/ALGOTRADE/Inserção de dados/OUTPUT DATA COLLAB/.csv', index=False)

df
# Out:
# /content
# Price         Date      Time       Open       High        Low      Close  \
# Ticker                        GOLD11.SA  GOLD11.SA  GOLD11.SA  GOLD11.SA
# 0       2020-12-16  00:00:00  12.000000  18.900000  10.160000  10.300000
# 1       2020-12-17  00:00:00  10.400000  10.600000  10.150000  10.300000
# 2       2020-12-18  00:00:00  10.380000  10.410000  10.250000  10.320000
# 3       2020-12-21  00:00:00  10.400000  10.530000  10.330000  10.380000
# 4       2020-12-22  00:00:00  10.440000  10.450000  10.320000  10.390000
# ...            ...       ...        ...        ...        ...        ...
# 1156    2025-08-11  00:00:00  19.139999  19.160000  19.020000  19.030001
# 1157    2025-08-12  00:00:00  18.990000  19.049999  18.820000  18.830000
# 1158    2025-08-13  00:00:00  18.840000  19.010000  18.840000  18.930000
# 1159    2025-08-14  00:00:00  18.950001  18.969999  18.820000  18.870001
# 1160    2025-08-15  00:00:00  18.860001  18.910000  18.780001  18.820000
#
# Price     Volume
# Ticker GOLD11.SA
# 0         163307
# 1         457235
# 2         773278
# 3         314610
# 4         496482
# ...          ...
# 1156     1423176
# 1157     2536449
# 1158     1066875
# 1159     1010889
# 1160     1084173
#
# [1161 rows x 7 columns]

# %%
# Out:
# UsageError: Line magic function `%notebook.github.com/Save` not found.
